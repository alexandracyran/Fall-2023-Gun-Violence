# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
from wordcloud import WordCloud

# %%
shooting = pd.read_csv('shooting-1982-2023.csv')

# %%
shooting.head()
# Out:
#                                   case                   location      date  \
# 0  Nashville religious school shooting              Nashville, TN   3-27-23
# 1   Michigan State University shooting     East Lansing, Michigan   2-13-23
# 2         Half Moon Bay spree shooting  Half Moon Bay, California   1-23-23
# 3        LA dance studio mass shooting  Monterey Park, California   1-21-23
# 4            Virginia Walmart shooting       Chesapeake, Virginia  11-22-22
#
#                                              summary  fatalities injured  \
# 0  Audrey Hale, 28, who was a former student at t...           6       1
# 1  Anthony D. McRae, 43, opened fire at Berkey Ha...           3       5
# 2  Chunli Zhao, 67, suspected of carrying out the...           7       1
# 3  Huu Can Tran, 72, fled the scene in a white va...          11      10
# 4  Andre Bing, 31, who worked as a supervisor at ...           6       6
#
#   total_victims location.1 age_of_shooter prior_signs_mental_health_issues  \
# 0             6     School             28                                -
# 1             8     School             43                                -
# 2             8  workplace             67                                -
# 3            21      Other             72                              yes
# 4            12  Workplace             31                                -
#
#    ... weapons_obtained_legally where_obtained  \
# 0  ...                        -              -
# 1  ...                      yes              -
# 2  ...                        -              -
# 3  ...                        -              -
# 4  ...                        -              -
#
#                                       weapon_type weapon_details   race  \
# 0      semiautomatic rifle, semiautomatic handgun              -      -
# 1                          semiautomatic handguns              -  Black
# 2                           semiautomatic handgun              -  Asian
# 3  semiautomatic assault weapon (Details pending)              -  Asian
# 4                           semiautomatic handgun              -  Black
#
#                                       gender latitude longitude   type  year
# 0  F (identified as transgender, per police)        -         -   Mass  2023
# 1                                          M        -         -   Mass  2023
# 2                                          M        -         -  Spree  2023
# 3                                          M        -         -   Mass  2023
# 4                                          M        -         -   Mass  2022
#
# [5 rows x 21 columns]

# %%
shooting.shape
# Out:
# (141, 21)

# %% [markdown]
# ### Data Cleaning

# %%
for i in shooting.columns:
    shooting[i].replace({"-":np.nan},inplace=True)

# %%
shooting.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 141 entries, 0 to 140
# Data columns (total 21 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   case                              141 non-null    object
#  1   location                          141 non-null    object
#  2   date                              141 non-null    object
#  3   summary                           141 non-null    object
#  4   fatalities                        141 non-null    int64
#  5   injured                           141 non-null    object
#  6   total_victims                     141 non-null    object
#  7   location.1                        141 non-null    object
#  8   age_of_shooter                    139 non-null    object
#  9   prior_signs_mental_health_issues  113 non-null    object
#  10  mental_health_details             99 non-null     object
#  11  weapons_obtained_legally          124 non-null    object
#  12  where_obtained                    95 non-null     object
#  13  weapon_type                       141 non-null    object
#  14  weapon_details                    115 non-null    object
#  15  race                              128 non-null    object
#  16  gender                            141 non-null    object
#  17  latitude                          126 non-null    object
#  18  longitude                         126 non-null    object
#  19  type                              141 non-null    object
#  20  year                              141 non-null    int64
# dtypes: int64(2), object(19)
# memory usage: 23.3+ KB

# %%
shooting.isna().sum()
# Out:
# case                                 0
# location                             0
# date                                 0
# summary                              0
# fatalities                           0
# injured                              0
# total_victims                        0
# location.1                           0
# age_of_shooter                       2
# prior_signs_mental_health_issues    28
# mental_health_details               42
# weapons_obtained_legally            17
# where_obtained                      46
# weapon_type                          0
# weapon_details                      26
# race                                13
# gender                               0
# latitude                            15
# longitude                           15
# type                                 0
# year                                 0
# dtype: int64

# %%
shooting['age_of_shooter'] = pd.to_numeric(shooting['age_of_shooter'], errors = 'coerce')
shooting['age_of_shooter'] = shooting['age_of_shooter'].fillna(round(shooting['age_of_shooter'].mean()))

# %%
shooting['total_victims'] = pd.to_numeric(shooting['total_victims'], errors = 'coerce')
shooting['injured'] = pd.to_numeric(shooting['injured'], errors = 'coerce')
shooting['fatalities'] = pd.to_numeric(shooting['fatalities'], errors = 'coerce')

# %%
shooting['gender'].value_counts()
# Out:
# Male                                         70
# M                                            65
# Male & Female                                 2
# Female                                        2
# F (identified as transgender, per police)     1
# F                                             1
# Name: gender, dtype: int64

# %%
shooting['gender'] = shooting['gender'].replace({"M": "Male"})
shooting['gender'] = shooting['gender'].replace({"Male & Female": "Male"})
shooting['gender'] = shooting['gender'].replace({"F (identified as transgender, per police)": "Other"})
shooting['gender'] = shooting['gender'].replace({"F": "Female"})
shooting['gender'].value_counts()
# Out:
# Male      137
# Female      3
# Other       1
# Name: gender, dtype: int64

# %%
shooting['prior_signs_mental_health_issues'].value_counts()
# Out:
# Yes         58
# Unclear     23
# No          17
# yes          8
# TBD          5
# Unknown      1
# Unclear      1
# Name: prior_signs_mental_health_issues, dtype: int64

# %%
replacement_mapping = {
    'TBD': 'Unknown',
    'Unclear ': 'Unknown',
    'Unclear': 'Unknown',
    'yes': 'Yes',
    'yes ': 'Yes',
    ' yes': 'Yes',
    'no': 'No',
    ' no': 'No',
    ' no ': 'No'
}

# Replace values in the 'prior_signs_mental_health_issues' column using the mapping dictionary
shooting['prior_signs_mental_health_issues'] = shooting['prior_signs_mental_health_issues'].replace(replacement_mapping)

shooting['prior_signs_mental_health_issues'] = shooting['prior_signs_mental_health_issues'].fillna(shooting['prior_signs_mental_health_issues'].mode()[0])
shooting['prior_signs_mental_health_issues'].value_counts()
# Out:
# Yes        94
# Unknown    30
# No         17
# Name: prior_signs_mental_health_issues, dtype: int64

# %%
shooting['mental_health_details'] = shooting['mental_health_details'].fillna('Unknown')

# %%
shooting['weapons_obtained_legally'].value_counts()
# Out:
# Yes                                                                                                                                    81
# No                                                                                                                                     16
# yes                                                                                                                                     9
# TBD                                                                                                                                     7
# Unknown                                                                                                                                 6
# \nYes                                                                                                                                   2
# Kelley passed federal criminal background checks; the US Air Force failed to provide information on his criminal history to the FBI     1
# Yes ("some of the weapons were purchased legally and some of them may not have been")                                                   1
# Yes                                                                                                                                     1
# Name: weapons_obtained_legally, dtype: int64

# %%
shooting['weapons_obtained_legally'].isna().sum()
# Out:
# 17

# %%
replacement_mapping = {
    'yes': 'Yes',
    'yes ': 'Yes',
    ' yes': 'Yes',
    '\nYes': 'Yes',
    """Yes ("some of the weapons were purchased legally and some of them may not have been")""": 'Yes',
    'Yes ': 'Yes',
    'no': 'No',
    'no ': 'No',
    ' no': 'No',
    'TBD': 'Unknown',
    'Unknown': 'Unknown',
    "Kelley passed federal criminal background checks; the US Air Force failed to provide information on his criminal history to the FBI": 'Unknown'
}

# Replace values in the 'weapons_obtained_legally' column using the mapping dictionary
shooting['weapons_obtained_legally'] = shooting['weapons_obtained_legally'].replace(replacement_mapping)
shooting['weapons_obtained_legally'].value_counts()
# Out:
# Yes        94
# No         16
# Unknown    14
# Name: weapons_obtained_legally, dtype: int64

# %%
shooting['weapons_obtained_legally'] = shooting['weapons_obtained_legally'].fillna(shooting['weapons_obtained_legally'].mode()[0])

# %%
shooting['weapons_obtained_legally'].isna().sum()
# Out:
# 0

# %%
shooting['weapon_details'].isna().sum()
# Out:
# 26

# %%
shooting['weapon_details'] = shooting['weapon_details'].fillna(shooting['weapon_details'].mode()[0])

# %%
shooting['weapon_details'].value_counts()
# Out:
# .45-caliber semiautomatic handgun                                                                                                          28
# 9mm handgun                                                                                                                                 2
# 9mm semiautomatic handgun                                                                                                                   2
# AR-15                                                                                                                                       2
# AK-47-style rifle, per authorities                                                                                                          2
#                                                                                                                                            ..
# 9 mm handgun (ammo used unclear)                                                                                                            1
# Zastava Serbia AK-47-style rifle, Glock Model 22 .40-caliber handgun; high-capacity magazines (30 rounds)                                   1
# Sig Sauer MCX rifle, Glock 17 9mm; high-capacity magazines (30 rounds)                                                                      1
# Izhmash-Saiga 5.45mm (AK-style) semiautomatic rifle with large capacity magazines; Glock 9mm handgun, .25-caliber semiautomatic handgun     1
# Mossberg 500 Persuader pump-action shotgun with pistol grip                                                                                 1
# Name: weapon_details, Length: 110, dtype: int64

# %%
shooting['race'].isna().sum()
# Out:
# 13

# %%
shooting['race'] = shooting['race'].fillna(shooting['race'].mode()[0])

# %%
shooting['race'].value_counts()
# Out:
# white              54
# White              31
# Black              16
# Latino             11
# Asian              10
# black               9
# Other               5
# Native American     3
# White               1
# unclear             1
# Name: race, dtype: int64

# %%
replacement_mapping = {
   'white': 'White',
    'White ': 'White',
    'black': 'Black',
    'unclear': 'Unclear'
}

# Replace values in the 'weapons_obtained_legally' column using the mapping dictionary
shooting['race'] = shooting['race'].replace(replacement_mapping)
shooting['race'].value_counts()
# Out:
# White              86
# Black              25
# Latino             11
# Asian              10
# Other               5
# Native American     3
# Unclear             1
# Name: race, dtype: int64

# %%
shooting['where_obtained'].value_counts()
# Out:
# Unknown                                         15
# Unclear                                          4
# TBD                                              3
# Purchased from an individual                     2
# Dance's Sporting Goods; Colonial Heights, VA     1
#                                                 ..
# Assembled a rifle out of component parts.        1
# Florida Gun Center                               1
# Sharpshooters Small Arms Range                   1
# Local gun store in Killeen, Guns Galore          1
# Garcia Gun Center in Hialeah, Fla.               1
# Name: where_obtained, Length: 75, dtype: int64

# %%
shooting['where_obtained'] = shooting['where_obtained'].fillna("Unknown")

# %%
shooting['where_obtained'].isna().sum()
# Out:
# 0

# %%
shooting['location.1'].value_counts()
# Out:
# Other          50
# Workplace      45
# School         22
# Religious       7
# Military        6
# workplace       5
# Other\n         3
# religious       1
# Airport         1
# \nWorkplace     1
# Name: location.1, dtype: int64

# %%
replacement_mapping = {
   'Other\n': 'Other',
    'workplace': 'Workplace',
    '\nWorkplace': 'Workplace',
    'Other\n': 'Other',
    'religious': 'Religious'
}

# Replace values in the 'location.1' column using the mapping dictionary
shooting['location.1'] = shooting['location.1'].replace(replacement_mapping)
shooting['location.1'].value_counts()
# Out:
# Other        53
# Workplace    51
# School       22
# Religious     8
# Military      6
# Airport       1
# Name: location.1, dtype: int64

# %%
shooting['state'] = shooting['location'].str.split(",").str[-1].str.strip()

# %%
shooting['location'].isna().sum()
# Out:
# 0

# %%
shooting['state'].value_counts()
# Out:
# California        25
# Texas             12
# Florida           12
# Colorado           8
# Washington         7
# Pennsylvania       5
# New York           5
# Wisconsin          5
# Illinois           5
# Michigan           4
# Ohio               4
# Virginia           4
# Maryland           4
# Connecticut        3
# North Carolina     3
# Georgia            3
# Kentucky           2
# Minnesota          2
# South Carolina     2
# Missouri           2
# Tennessee          2
# Nevada             2
# Indiana            2
# Oklahoma           2
# Oregon             2
# Utah               1
# Arkansas           1
# Mississippi        1
# Massachusetts      1
# Hawaii             1
# Nebraska           1
# TN                 1
# Arizona            1
# D.C.               1
# Kansas             1
# Lousiana           1
# New Jersey         1
# Alabama            1
# Iowa               1
# Name: state, dtype: int64

# %% [markdown]
# ### Data Analysis

# %%
correlation_matrix = shooting.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# #### - There is a strong positive correlation between fatalities and injuries (0.65), fatalities and total victims (0.73), and injuries and total victims (0.99).
# #### - The age of the shooter shows weak positive correlations with fatalities (0.03), injuries (0.14), and total victims (0.13).
# #### - The year of the incident has weak negative correlations with fatalities (-0.04), injuries (0.04), and total victims (0.03). This suggests a slight trend of fewer casualties in more recent years.

# %% [markdown]
# ### Shooter Analysis

# %%
# Distribution of shooter ages
plt.figure(figsize=(5, 6))
sns.histplot(shooting['age_of_shooter'], bins=20, kde=True, color='skyblue')
plt.title('Distribution of Shooter Ages')
plt.xlabel('Age of Shooter')
plt.ylabel('Frequency')
plt.show()

# %%
# Shooter analysis by gender and age
plt.figure(figsize=(8, 6))
sns.scatterplot(x = 'age_of_shooter', y = 'fatalities', hue = 'gender', data = shooting, palette = 'Set1')
plt.title('Shooter Analysis by Gender and Age')
plt.xlabel('Age of Shooter')
plt.ylabel('Fatalities')
plt.show()

# %%
# Distribution of shooter genders
gender_order = shooting['gender'].value_counts().index
plt.figure(figsize = (4, 3))
sns.countplot(x = 'gender', data = shooting, palette = 'viridis', order = gender_order)
plt.title('Distribution of Shooter Genders')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
# Prior signs of mental health issues
plt.figure(figsize = (4, 3))
sns.countplot(x ='prior_signs_mental_health_issues', data = shooting, palette = 'pastel')
plt.title('Prior Signs of Mental Health Issues')
plt.xlabel('Prior Signs of Mental Health Issues')
plt.ylabel('Count')
plt.show()

# %%
# Weapons obtained legally
plt.figure(figsize=(4, 3))
sns.countplot(x = 'weapons_obtained_legally', data = shooting, palette = 'muted')
plt.title('Weapons Obtained Legally')
plt.xlabel('Weapons Obtained Legally')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### Location Analysis

# %%
# Distribution of shootings by location
location_order = shooting['location.1'].value_counts().index
plt.figure(figsize=(12, 6))
sns.countplot(x='location.1', data=shooting, palette='viridis', order = location_order)
plt.title('Distribution of Shootings by Location')
plt.xlabel('Location Type')
plt.ylabel('Count')
#plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.show()

# %%
# Distribution of shootings by state
plt.figure(figsize=(12, 6))
sns.countplot(x='state', data=shooting, palette='Set2')
plt.title('Distribution of Shootings by State')
plt.xlabel('State')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.show()

# %%
top_5_state = shooting['state'].value_counts().head(5)
plt.figure(figsize=(12, 6))
sns.countplot(x = 'state', data = shooting, order = top_5_state.index, palette = 'Set2')
plt.title('Top 5 States')
plt.xlabel('State')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### Weapon Analysis

# %%
# Word cloud for weapon types
weapon_types_text = ' '.join(shooting['weapon_type'].astype(str))
wordcloud_types = WordCloud(width=800, height=400, background_color='white').generate(weapon_types_text)

# Plot the word cloud for weapon types
plt.figure(figsize=(8, 5))
plt.imshow(wordcloud_types, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of Weapon Types')
plt.show()

# %%
# Word cloud for weapon details
weapon_details_text = ' '.join(shooting['weapon_details'].astype(str))
wordcloud_details = WordCloud(width=800, height=400, background_color='white').generate(weapon_details_text)

# Plot the word cloud for weapon details
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud_details, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of Weapon Details')
plt.show()

# %% [markdown]
# #### Mental Health

# %%
# Word cloud for weapon types
mental_health_text = ' '.join(shooting['mental_health_details'].astype(str).replace(['Unknown','year','told',' said','problem','according','described'], '').values)
wordcloud_types = WordCloud(width=800, height=400, background_color='white').generate(mental_health_text)

# Plot the word cloud for weapon types
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud_types, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of Mental Health Details')
plt.show()
